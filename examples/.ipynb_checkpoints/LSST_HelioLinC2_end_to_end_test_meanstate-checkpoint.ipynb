# %% [markdown]
# # LSST Solar System Processing
#
# ## Linking of Observations from JPL Veres & Chesley dataset via HelioLinC2
#
# ### Algorithm:
#
# Based on HelioLinC (Holman et al. 2018) we transform topocentric observations to heliocentric states assuming a distance and radial velocity.
# The resulting 3D positions are collected into tracklets. Tracklets contain at least two observations and can, thus, be used to create velocity vectors.
# A tracklet + velocity vector is called an "arrow".
# Arrows are propagated to a common epoch using spiceypy's 2body propagator, and then clustered using dbscan.
#
# ### Implementation:
# S. Eggl 20191215

# %%
# Solar System Processing functions
import heliolinc2 as ls
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8f0f2d6c5416> in <module>
#       1 # Solar System Processing functions
# ----> 2 import heliolinc2 as ls
#
# ModuleNotFoundError: No module named 'heliolinc2'

# %%
import constants as cnst
import vector as vec
import transforms as tr
import propagate as prop
import ephemeris as ephem
import filterclusters as fc
import performancecheck as pc
import plot as pl

# %%
#Accelerators
import numpy as np

#Database
import pandas as pd

#Plotting
import matplotlib
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 12}

matplotlib.rc('font', **font)

import matplotlib.pyplot as plt
from matplotlib.pyplot import cm

#Timing
import time
from datetime import datetime

# %%
# Joblib prallelization
import joblib
from joblib.externals.loky import set_loky_pickler
from joblib import parallel_backend
from joblib import wrap_non_picklable_objects
from joblib import Parallel, delayed

# %%
# Progress bar for joblib processes
import contextlib
from tqdm import tqdm

@contextlib.contextmanager
def tqdm_joblib(tqdm_object):
    """Context manager to patch joblib to report into tqdm progress bar given as argument"""
    class TqdmBatchCompletionCallback:
        def __init__(self, time, index, parallel):
            self.index = index
            self.parallel = parallel

        def __call__(self, index):
            tqdm_object.update()
            if self.parallel._original_iterator is not None:
                self.parallel.dispatch_next()

    old_batch_callback = joblib.parallel.BatchCompletionCallBack
    joblib.parallel.BatchCompletionCallBack = TqdmBatchCompletionCallback
    try:
        yield tqdm_object
    finally:
        joblib.parallel.BatchCompletionCallBack = old_batch_callback
        tqdm_object.close()

# %% [markdown]
# ## SIMULATED OBSERVATIONS
#
#
# 1) Select observations from JPL Dataset

# %%
# %%time
# Veres & Chesley 2017, 5deg x 5deg, 14 days 
dfveres= pd.read_csv('Veres_5x5deb_14nights.tar.gz',sep=',', skiprows=0).dropna().astype({'objId': 'int64','night': 'int32', 'obsId':'int64'} )
# Out:
# CPU times: user 155 ms, sys: 25 ms, total: 180 ms
# Wall time: 181 ms

# %%
dfjpl=dfveres.rename(columns={"Veres_5x5deb_14nights.csv": "obj"})

# %% [markdown]
# 2) Extract epochs of observations and query JPL Horizons for the corresponding observer states

# %%
#Observer location MPC code
observer_location='I11'
#Epochs of observation
obs_epochs=tr.mjd2jd(dfjpl['time'].values)
#time between observations
ephemeris_dt='1h'

# %%
[observer_xyz, observer_vxyz]=ephem.getObserverStates(obs_epochs,observer_location,ephemeris_dt)
# Out:
# [[-8.18439761e-01 -5.85272681e-01 -2.72019734e-05]
#  [-8.18038982e-01 -5.85865749e-01 -2.38197419e-05]
#  [-8.17635440e-01 -5.86459367e-01 -2.00717895e-05]
#  ...
#  [-6.47114734e-01 -7.75424965e-01 -1.47328968e-05]
#  [-6.46575496e-01 -7.75895816e-01 -1.09099689e-05]
#  [-6.46033435e-01 -7.76365937e-01 -7.23589057e-06]]
# [[ 9.58777826e-03 -1.42226215e-02  7.48709655e-05]
#  [ 9.65087522e-03 -1.42425042e-02  8.65477870e-05]
#  [ 9.71976234e-03 -1.42487759e-02  9.23247140e-05]
#  ...
#  [ 1.29073691e-02 -1.13043206e-02  9.14304993e-05]
#  [ 1.29759779e-02 -1.12940712e-02  9.10104058e-05]
#  [ 1.30422318e-02 -1.12693680e-02  8.43267519e-05]]

# %%
dfobs=dfjpl

# %%
dfobs['x_obs']=observer_xyz[:,0]
dfobs['y_obs']=observer_xyz[:,1]
dfobs['z_obs']=observer_xyz[:,2]
dfobs['vx_obs']=observer_vxyz[:,0]
dfobs['vy_obs']=observer_vxyz[:,1]
dfobs['vz_obs']=observer_vxyz[:,2]

# %%
plot_field(dfobs)

# %% [markdown]
# ## Signal to Noise in the chosen field

# %%
# collect data from different categories
dfobs_FD=dfobs.iloc[dfobs['obj'].values=='FD']
dfobs_NS=dfobs.iloc[dfobs['obj'].values=='NS']
dfobs_obj=dfobs.drop(dfobs_FD.index).drop(dfobs_NS.index)
SNR_field=len(dfobs_obj.index)/(len(dfobs_NS.index)+len(dfobs_FD.index))
print(SNR_field)
# Out:
# 0.26722774053595605

# %% [markdown]
# ## Source Density per square degree

# %%
np.rint(len(dfobs.index)/(5*5))
# Out:
# 3108.0

# %% [markdown]
# Check observation dataframe: must contain time, RA, DEC, x_obs, y_obs, z_obs, vx_obs, vy_obs, vz_obs, night, obsId, objId

# %%
dfobs[0:10]
# Out:
#          obj          time          RA        DEC     x_obs     y_obs  \
# 0  S1009GjOa  52391.002282  171.368899 -12.504937 -0.808597 -0.599239
# 1  S1001QUsa  52391.002282  169.318742 -13.021633 -0.808597 -0.599239
# 2  S10036B8a  52391.002282  170.375067 -12.218251 -0.808597 -0.599239
# 3  S100aAWQa  52391.002282  171.392970 -14.233830 -0.808597 -0.599239
# 4  S1001DTsa  52391.002282  171.308411 -14.222651 -0.808597 -0.599239
# 5  S1008Q8Da  52391.002282  170.582069 -12.248939 -0.808597 -0.599239
# 6  S100dQNoa  52391.002282  168.832741 -12.103015 -0.808597 -0.599239
# 7  S1004whRa  52391.002282  171.183715 -13.576337 -0.808597 -0.599239
# 8  S1000gIia  52391.002282  169.879839 -11.317941 -0.808597 -0.599239
# 9  S100a4cua  52391.002282  170.612881 -11.978926 -0.808597 -0.599239
#
#       z_obs    vx_obs    vy_obs    vz_obs  night  obsId  objId
# 0 -0.000026  0.009826 -0.014054  0.000076      0      0    839
# 1 -0.000026  0.009826 -0.014054  0.000076      0      1    164
# 2 -0.000026  0.009826 -0.014054  0.000076      0      2    319
# 3 -0.000026  0.009826 -0.014054  0.000076      0      3   1580
# 4 -0.000026  0.009826 -0.014054  0.000076      0      4    144
# 5 -0.000026  0.009826 -0.014054  0.000076      0      5    766
# 6 -0.000026  0.009826 -0.014054  0.000076      0      6   1835
# 7 -0.000026  0.009826 -0.014054  0.000076      0      7    491
# 8 -0.000026  0.009826 -0.014054  0.000076      0      8     96
# 9 -0.000026  0.009826 -0.014054  0.000076      0      9   1570

# %% [markdown]
# Since we are looking at a fraction of the sky, how many nights do we actually observe?

# %%
df_grouped_by_night=dfobs.groupby('night')

# %%
len(df_grouped_by_night.groups)
# Out:
# 7

# %%
df_grouped_by_night.groups.keys()
# Out:
# dict_keys([0, 1, 3, 6, 10, 11, 13])

# %% [markdown]
# ## Run HelioLinC2

# %% [markdown]
# Choose HelioLinC2 clustering parameters

# %%
# Clustering radius for heliocentric positions projected from observations [au]
cr_obs=0.02
# Clustering radius for propagated arrows [au]
cr_arrows=0.002
# max temporal separation for tracklet observations (days)
ct_max=8/24
# min temporal separation for tracklet observations, e.g. exposure time (days)
ct_min=15/86400 
# Minimum number of arrows to be clustered ('DBSCAN only')
min_samples=3

# %%
#test

# %load_ext autoreload

# %autoreload

# %reload_ext heliolinc2

# ls.heliolinc2(dfobs, 2, 0, cr_obs, cr_arrows, ct_min, ct_max, min_samples=min_samples,
#                                        clustering_algorithm='dbscan', light_time=False, 
#                                        verbose=True, n_jobs=1)

# %%
# define range of heliocentric distances
rall=np.arange(2,3.7,0.05)

# define range of heliocentric radial velocities
drdtall=np.arange(-0.05,0.051,0.01)

# Iterator for joblib based paralellization
rrdot=np.array(np.meshgrid(rall,drdtall)).T.reshape(-1,2)

# How many configuraitons do we have to run?
len(rrdot)
# Out:
# 374

# %%
with tqdm_joblib(tqdm(desc="HelioLinC2", total=len(rrdot))) as progress_bar:
    clusters_df=Parallel(n_jobs=14)(delayed(ls.heliolinc2)
                                      (dfobs, r, drdt, cr_obs, cr_arrows, ct_min, ct_max, min_samples=min_samples,
                                       clustering_algorithm='dbscan', light_time=False, 
                                       verbose=False, n_jobs=1) 
                                       for r, drdt in rrdot )
# Out:
# HelioLinC2:   4%|▍         | 15/374 [31:47<20:50:03, 208.92s/it] /epyc/projects/pytrax_play/envs/pytrax_s/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning:
#
# A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#
# HelioLinC2: 100%|██████████| 374/374 [3:10:32<00:00, 30.57s/it]

# %%
print('total number of dataframes:',len(clusters_df))
# Out:
# total number of dataframes: 374

# %%
clustered_observations = (pd.concat(clusters_df)).reset_index(drop=True)  
clustered_observations['clusterId']=clustered_observations.index
len(clustered_observations)
# Out:
# 273223

# %%
#%load_ext autoreload

# %autoreload

# %reload_ext filterclusters

# %%
# obs_lens=[]

# for index, row in clustered_observations.iterrows():
#     #print(row['obsId'])
#     obs_lens.append(len(row['obsId']))

# %%
# plt.figure(dpi=150)
# plt.hist(obs_lens,bins=range(1,20))
# plt.ylim(1,)
# plt.xlim(1,20)
# plt.xlabel('number of observations in cluster')
# plt.ylabel('number of clusters')

# %%
# idx=clustered_observations['obsId'][0]

# %%
# l_dict=zip(idx,idx)

# %%
# df=dfobs[[x in idx for x in dfobs['obsId']]]

# %%
# df

# %%
# drop_idx=fc.filterClusters(dfobs, clustered_observations, rms_max=3, filter_type='mean_state')
#

# %%
# def parallelize_filter(df, dfobs, func, n_cores=12):
#     df_split = np.array_split(df, n_cores)
#     pool = Pool(n_cores)
#     df = pd.concat(pool.map(func, df_split))
#     pool.close()
#     pool.join()
#     return df

# %%
n_cores=25

dfobs_n=[]
for i in range(n_cores):
    dfobs_n.append(dfobs)

df_split = np.array_split(clustered_observations, n_cores)

# %%
with tqdm_joblib(tqdm(desc="HelioLinC2", total=n_cores)) as progress_bar:
    drop_idx=Parallel(n_jobs=n_cores)(delayed(fc.filterClusters)
                       (dfobs_n[i], df_split[i] , rms_max=2, filter_type='mean_state') for i in range(n_cores) )
# Out:
# HelioLinC2: 100%|██████████| 25/25 [3:54:54<00:00, 563.79s/it]

# %%
drop_idx
# Out:
# [       clusterId                         obsId    r  drdt  cluster_epoch  \
#  101          101               [4, 2521, 5878]  2.0 -0.05   52397.573056
#  133          133        [77, 2531, 3390, 5888]  2.0 -0.05   52397.573056
#  143          143        [87, 2532, 3398, 5890]  2.0 -0.05   52397.573056
#  290          290        [53, 2529, 3372, 5885]  2.0 -0.05   52397.573056
#  291          291       [171, 2560, 3480, 5916]  2.0 -0.05   52397.573056
#  ...          ...                           ...  ...   ...            ...
#  10714      10714         [21186, 28245, 39319]  2.0 -0.01   52397.573056
#  10717      10717         [21249, 28310, 39377]  2.0 -0.01   52397.573056
#  10720      10720         [21279, 28341, 39405]  2.0 -0.01   52397.573056
#  10722      10722         [21270, 28331, 39395]  2.0 -0.01   52397.573056
#  10834      10834  [41686, 42567, 44434, 45275]  2.0 -0.01   52397.573056
#
#              x_a       y_a       z_a      vx_a      vy_a      vz_a       rms
#  101   -1.913481 -0.502019 -0.294626 -0.049196 -0.003277 -0.014363  1.676941
#  133   -1.916374 -0.483641 -0.308446 -0.049272 -0.002180 -0.015350  1.831745
#  143   -1.914580 -0.488465 -0.312780 -0.049052 -0.002575 -0.016372  1.783608
#  290   -1.911367 -0.514709 -0.283764 -0.049099 -0.004260 -0.013220  1.927388
#  291   -1.914981 -0.501899 -0.283670 -0.049269 -0.003443 -0.013497  1.769093
#  ...         ...       ...       ...       ...       ...       ...       ...
#  10714 -1.936725 -0.450114 -0.212911 -0.007856 -0.009095 -0.001649  1.913441
#  10717 -1.936584 -0.439694 -0.234597 -0.007958 -0.008191 -0.002610  1.869277
#  10720 -1.939353 -0.436062 -0.217974 -0.007986 -0.008454 -0.002110  1.794884
#  10722 -1.940878 -0.430996 -0.214597 -0.007902 -0.008733 -0.002573  1.097708
#  10834 -1.914496 -0.483252 -0.318032 -0.007480 -0.009545 -0.003203  1.867298
#
#  [1259 rows x 12 columns],
#         clusterId                         obsId     r  drdt  cluster_epoch  \
#  10943      10943  [40762, 41527, 43500, 44270]  2.00 -0.01   52397.573056
#  10950      10950  [40729, 41491, 43469, 44230]  2.00 -0.01   52397.573056
#  120221  0.007826  1.012850
#  120222  0.008038  1.618578
#  120223  0.007353  0.728396
#  ...          ...       ...
#  131045 -0.014489  0.968466
#  131087 -0.013338  1.842382
#  131111 -0.012021  1.756916
#  131116 -0.012748  1.888838
#  131122 -0.012951  1.569607
#
#  [1207 rows x 12 columns],
#          clusterId                                obsId     r  drdt  \
#  131213     131213                [22870, 29993, 37070]  2.50 -0.05
#  131228     131228  [21125, 25024, 28187, 32191, 36667]  2.50 -0.05
#  131247     131247         [25170, 29816, 32346, 36807]  2.50 -0.05
#  131289     131289  [21361, 22871, 28412, 29994, 39469]  2.50 -0.05
#  131302     131302  [21197, 22682, 28255, 29796, 39329]  2.50 -0.05
#  ...           ...                                  ...   ...   ...
#  141989     141989                [56554, 70735, 76477]  2.55 -0.03
#  141990     141990         [56986, 62567, 71154, 76654]  2.55 -0.03
#  141993     141993         [56313, 62302, 70496, 76388]  2.55 -0.03
#  141998     141998                [62314, 70527, 76398]  2.55 -0.03
#  142002     142002         [56569, 60149, 68849, 70750]  2.55 -0.03
#
#          cluster_epoch       x_a       y_a       z_a      vx_a      vy_a  \
#  131213   52397.573056 -2.441760 -0.412167 -0.342094 -0.049071 -0.002825
#  131228   52397.573056 -2.441708 -0.386490 -0.371621 -0.048980 -0.001288
#  131247   52397.573056 -2.443572 -0.396984 -0.347240 -0.049101 -0.002042
#  131289   52397.573056 -2.445748 -0.397392 -0.331125 -0.049119 -0.002125
#  131302   52397.573056 -2.448967 -0.397871 -0.305553 -0.049276 -0.002414
#  ...               ...       ...       ...       ...       ...       ...
#  141989   52397.573056 -2.476380 -0.449628 -0.404667 -0.028816 -0.005642
#  141990   52397.573056 -2.477007 -0.445914 -0.405032 -0.028636 -0.006361
#  141993   52397.573056 -2.479033 -0.432081 -0.408482 -0.028175 -0.007227
#  141998   52397.573056 -2.477596 -0.443163 -0.404304 -0.028990 -0.004827
#  142002   52397.573056 -2.473323 -0.415868 -0.456593 -0.028370 -0.005919
#
#              vz_a       rms
#  131213 -0.010959  1.700367
#  131228 -0.012730  1.997861
#  131247 -0.011443  1.683366
#  131289 -0.011469  1.410000
#  131302 -0.010137  1.239356
#  ...          ...       ...
#  141989 -0.007967  1.562886
#  141990 -0.008240  1.377903
#  141993 -0.009873  1.755968
#  141998 -0.007818  1.906143
#  142002 -0.009710  1.270059
#
#  [870 rows x 12 columns],
#          clusterId                                obsId     r  drdt  \
#  142110     142110         [56645, 61491, 68147, 70827]  2.55 -0.03
#  142113     142113         [53821, 56295, 66071, 70480]  2.55 -0.03
#  142117     142117         [62394, 64018, 74503, 76487]  2.55 -0.03
#  142134     142134         [62538, 64246, 74725, 76623]  2.55 -0.03
#  142138     142138         [62442, 64092, 74578, 76527]  2.55 -0.03
#  ...           ...                                  ...   ...   ...
#  152816     152816                [25384, 32553, 36996]  2.60  0.02
#  152826     152826                [25211, 32384, 36840]  2.60  0.02
#  152878     152878                [25508, 32676, 37113]  2.60  0.02
#  152939     152939  [21361, 22871, 28412, 29994, 39469]  2.60  0.02
#  152993     152993  [21197, 22682, 28255, 29796, 39329]  2.60  0.02
#
#          cluster_epoch       x_a       y_a       z_a      vx_a      vy_a  \
#
#  196643   52397.573056 -2.840651 -0.349699 -0.470645  0.031299 -0.016046
#
#              vz_a       rms
#  185828 -0.012853  1.856281
#  185843 -0.012298  1.319808
#  185858 -0.014216  1.268162
#  185920 -0.012616  1.972042
#  186049 -0.011403  1.770608
#  ...          ...       ...
#  196524  0.002820  1.232877
#  196527  0.002105  0.957922
#  196533  0.003374  1.977285
#  196594  0.005131  1.998982
#  196643  0.005928  1.567769
#
#  [501 rows x 12 columns],
#          clusterId                                       obsId    r  drdt  \
#  196803     196803         [21197, 22682, 28255, 29796, 39329]  2.9  0.03
#  196883     196883                       [60109, 62360, 76448]  2.9  0.03
#  196906     196906  [56197, 60272, 62260, 68977, 70387, 76345]  2.9  0.03
#  196907     196907         [56974, 60432, 62558, 69135, 76644]  2.9  0.03
#  196908     196908                [56986, 62567, 71154, 76654]  2.9  0.03
#  ...           ...                                         ...  ...   ...
#  207519     207519                       [60432, 62558, 76644]  3.0 -0.01
#  207521     207521                       [56554, 70735, 76477]  3.0 -0.01
#  207597     207597                [53814, 56287, 66063, 70473]  3.0 -0.01
#  207601     207601                       [63848, 70476, 74337]  3.0 -0.01
#  207604     207604                [53684, 65943, 74120, 74209]  3.0 -0.01
#
#          cluster_epoch       x_a       y_a       z_a      vx_a      vy_a  \
#  196803   52397.573056 -2.856974 -0.327943 -0.378078  0.031333 -0.015547
#  196883   52397.573056 -2.818837 -0.431105 -0.538331  0.032294 -0.013394
#  196906   52397.573056 -2.826762 -0.394268 -0.524807  0.032187 -0.013782
#  196907   52397.573056 -2.827874 -0.395983 -0.516956  0.032157 -0.013484
#  196908   52397.573056 -2.833620 -0.396639 -0.486507  0.032510 -0.014802
#  ...               ...       ...       ...       ...       ...       ...
#  207519   52397.573056 -2.925239 -0.383181 -0.542052 -0.008687 -0.007436
#  207521   52397.573056 -2.930672 -0.386726 -0.509611 -0.008679 -0.008389
#  207597   52397.573056 -2.948247 -0.300510 -0.464046 -0.008991 -0.007507
#  207601   52397.573056 -2.949615 -0.309901 -0.449525 -0.008829 -0.008409
#  207604   52397.573056 -2.954892 -0.318421 -0.406299 -0.009067 -0.007822
#
#              vz_a       rms
#  196803  0.004656  1.853687
#  196883  0.006476  1.718799
#  196906  0.006069  1.442668
#  196907  0.005917  1.566074
#  196908  0.005731  1.345336
#  ...          ...       ...
#  207519 -0.003858  1.880037
#  207521 -0.003158  1.830847
#  207597 -0.003386  1.174927
#  207601 -0.003566  0.991697
#  207604 -0.002565  1.425403
#
#  [484 rows x 12 columns],
#          clusterId                                       obsId    r  \
#  207659     207659         [24183, 25184, 31297, 32360, 36819]  3.0
#  207711     207711                       [20711, 27803, 37079]  3.0
#  207831     207831                [21197, 22682, 28255, 29796]  3.0
#  207930     207930  [56197, 60272, 62260, 68977, 70387, 76345]  3.0
#  207931     207931         [56197, 60272, 62260, 68977, 76345]  3.0
#  ...           ...                                         ...  ...
#  218242     218242                       [53697, 63727, 74222]  3.1
#  218313     218313         [24183, 25184, 31297, 32360, 36819]  3.1
#  218475     218475         [21197, 22682, 28255, 29796, 39329]  3.1
#  218550     218550  [56197, 60272, 62260, 68977, 70387, 76345]  3.1
#  218555     218555                       [56986, 71154, 76654]  3.1
#
#                  drdt  cluster_epoch       x_a       y_a       z_a      vx_a  \
#  207659  6.938894e-18   52397.573056 -2.932521 -0.366335 -0.516042  0.001621
#  207711  6.938894e-18   52397.573056 -2.930825 -0.295515 -0.568660  0.001341
#  207831  6.938894e-18   52397.573056 -2.957441 -0.311083 -0.396136  0.001190
#  207930  6.938894e-18   52397.573056 -2.924381 -0.380869 -0.550065  0.001450
#  207931  6.938894e-18   52397.573056 -2.924334 -0.380806 -0.550358  0.001443
#  ...              ...            ...       ...       ...       ...       ...
#  218242 -4.000000e-02   52397.573056 -3.056324 -0.288100 -0.427606 -0.039337
#  218313 -3.000000e-02   52397.573056 -3.032182 -0.351983 -0.539528 -0.028280
#  218475 -3.000000e-02   52397.573056 -3.057907 -0.294214 -0.414265 -0.028952
#  218550 -3.000000e-02   52397.573056 -3.023289 -0.367270 -0.575765 -0.028685
#  218555 -3.000000e-02   52397.573056 -3.030858 -0.368377 -0.533902 -0.028659
#
#              vy_a      vz_a       rms
#  207659 -0.010424 -0.001914  1.997043
#  207711 -0.011583 -0.001119  1.431544
#  207831 -0.010489 -0.000762  1.861841
#  207930 -0.009273 -0.001390  1.678595
#  207931 -0.009283 -0.001345  1.699132
#  ...          ...       ...       ...
#  218242 -0.001364 -0.008968  1.255611
#  218313 -0.006119 -0.008961  1.995139
#  218475 -0.005429 -0.006201  1.847782
#  218550 -0.004854 -0.008680  1.894938
#  218555 -0.006462 -0.007928  1.785245
#
#  [422 rows x 12 columns],
#          clusterId                                       obsId    r  drdt  \
#  218645     218645                [56645, 61491, 68147, 70827]  3.1 -0.03
#  218678     218678                [56644, 64055, 70825, 74535]  3.1 -0.03
#  218701     218701                [53814, 56287, 66063, 70473]  3.1 -0.03
#  218717     218717  [53818, 56290, 63848, 66067, 70476, 74337]  3.1 -0.03
#  218718     218718                       [54020, 66260, 74530]  3.1 -0.03
#  ...           ...                                         ...  ...   ...
#  229210     229210                [54020, 64049, 66260, 74530]  3.2 -0.04
#  229219     229219                [53645, 63674, 65901, 74167]  3.2 -0.04
#  229220     229220         [53684, 65855, 65943, 74120, 74209]  3.2 -0.04
#  229222     229222                       [53697, 63727, 74222]  3.2 -0.04
#  229441     229441         [21197, 22682, 28255, 29796, 39329]  3.2 -0.03
#
#          cluster_epoch       x_a       y_a       z_a      vx_a      vy_a  \
#  218645   52397.573056 -3.034112 -0.223998 -0.592298 -0.028720 -0.003601
#  218678   52397.573056 -3.043087 -0.333196 -0.485057 -0.028973 -0.004795
#  218701   52397.573056 -3.048094 -0.282983 -0.485409 -0.029130 -0.003916
#  218717   52397.573056 -3.049630 -0.292621 -0.469961 -0.029008 -0.005000
#  218718   52397.573056 -3.052161 -0.299643 -0.449321 -0.028749 -0.004696
#  ...               ...       ...       ...       ...       ...       ...
#  229210   52397.573056 -3.152480 -0.282679 -0.468592 -0.038734 -0.003020
#  229219   52397.573056 -3.154638 -0.291100 -0.447899 -0.039330 -0.001100
#  229220   52397.573056 -3.155725 -0.284785 -0.443794 -0.039380 -0.002707
#  229222   52397.573056 -3.156697 -0.270652 -0.446115 -0.039313 -0.001327
#  229441   52397.573056 -3.158387 -0.277131 -0.432220 -0.028990 -0.005362
#
#              vz_a       rms
#  218645 -0.009341  1.353358
#  218678 -0.007702  1.049997
#  218701 -0.007452  1.300839
#  218717 -0.007584  1.055579
#  218718 -0.009442  1.457827
#  ...          ...       ...
#  229210 -0.011510  1.558702
#  229219 -0.009026  1.907029
#  229220 -0.007795  1.681131
#  229222 -0.008946  1.305285
#  229441 -0.006167  1.937802
#
#  [353 rows x 12 columns],
#          clusterId                                       obsId    r  drdt  \
#  229513     229513  [56197, 60272, 62260, 68977, 70387, 76345]  3.2 -0.03
#  229518     229518                       [56986, 71154, 76654]  3.2 -0.03
#  229600     229600                [56645, 61491, 68147, 70827]  3.2 -0.03
#  229648     229648                [53814, 56287, 66063, 70473]  3.2 -0.03
#  229661     229661                [56290, 63848, 70476, 74337]  3.2 -0.03
#  ...           ...                                         ...  ...   ...
#  239845     239845         [53684, 65855, 65943, 74120, 74209]  3.3 -0.03
#  239847     239847                       [53697, 63727, 74222]  3.3 -0.03
#  240123     240123                [53814, 56287, 66063, 70473]  3.3 -0.02
#  240130     240130                       [63848, 70476, 74337]  3.3 -0.02
#  240135     240135         [53684, 65855, 65943, 74120, 74209]  3.3 -0.02
#
#          cluster_epoch       x_a       y_a       z_a      vx_a      vy_a  \
#  229513   52397.573056 -3.122672 -0.353208 -0.600786 -0.028694 -0.004820
#  229518   52397.573056 -3.130659 -0.354394 -0.557120 -0.028674 -0.006482
#  229600   52397.573056 -3.132691 -0.203989 -0.617720 -0.028723 -0.003613
#  229648   52397.573056 -3.147992 -0.265366 -0.506383 -0.029133 -0.003904
#  229661   52397.573056 -3.149706 -0.275351 -0.490351 -0.029012 -0.005029
#  ...               ...       ...       ...       ...       ...       ...
#  239845   52397.573056 -3.256001 -0.267951 -0.461930 -0.029349 -0.004389
#  239847   52397.573056 -3.256835 -0.253081 -0.464500 -0.029294 -0.003079
#  240123   52397.573056 -3.247766 -0.247730 -0.527143 -0.019154 -0.005665
#  240130   52397.573056 -3.249646 -0.258237 -0.510657 -0.019017 -0.006743
#  240135   52397.573056 -3.256113 -0.267919 -0.461717 -0.019302 -0.006080
#
#              vz_a       rms
#  229513 -0.008624  1.972731
#  229518 -0.007874  1.858721
#  229600 -0.009299  1.408053
#  229648 -0.007409  1.353798
#  229661 -0.007549  1.120044
#  ...          ...       ...
#  239845 -0.005975  1.703105
#  239847 -0.007104  1.322288
#  240123 -0.005328  1.371966
#  240130 -0.005509  1.155392
#  240135 -0.004205  1.661034
#
#  [301 rows x 12 columns],
#          clusterId                                       obsId    r  \
#  240581     240581  [56197, 60272, 62260, 68977, 70387, 76345]  3.3
#  240582     240582         [56197, 60272, 62260, 68977, 76345]  3.3
#  240584     240584                       [62567, 71154, 76654]  3.3
#  240648     240648                [56855, 60337, 69045, 71027]  3.3
#  240652     240652                [56645, 61491, 68147, 70827]  3.3
#  ...           ...                                         ...  ...
#  251264     251264  [53818, 56290, 63848, 66067, 70476, 74337]  3.4
#  251267     251267                [54020, 64049, 66260, 74530]  3.4
#  251274     251274                [53645, 63674, 65901, 74167]  3.4
#  251275     251275         [53684, 65855, 65943, 74120, 74209]  3.4
#  251278     251278                       [53697, 63727, 74222]  3.4
#
#                  drdt  cluster_epoch       x_a       y_a       z_a      vx_a  \
#  240581  6.938894e-18   52397.573056 -3.222482 -0.338696 -0.625113  0.001202
#  240582  6.938894e-18   52397.573056 -3.222425 -0.338633 -0.625444  0.001193
#  240584  6.938894e-18   52397.573056 -3.230990 -0.340476 -0.579600  0.001368
#  240648  6.938894e-18   52397.573056 -3.224769 -0.271552 -0.645856  0.001037
#  240652  6.938894e-18   52397.573056 -3.231620 -0.184113 -0.642661  0.000914
#  ...              ...            ...       ...       ...       ...       ...
#  251264  3.000000e-02   52397.573056 -3.351266 -0.241371 -0.530515  0.031303
#  251267  3.000000e-02   52397.573056 -3.353957 -0.248832 -0.509350  0.031598
#  251274  3.000000e-02   52397.573056 -3.356662 -0.255838 -0.484800  0.031176
#  251275  3.000000e-02   52397.573056 -3.358156 -0.250732 -0.479234  0.031225
#  251278  3.000000e-02   52397.573056 -3.358619 -0.234400 -0.482785  0.031151
#
#              vy_a      vz_a       rms
#  240581 -0.009138 -0.001276  1.894549
#  240582 -0.009148 -0.001226  1.938530
#  240584 -0.010646 -0.001072  1.787830
#  240648 -0.009329 -0.001252  1.864174
#  240652 -0.009582 -0.001786  1.355033
#  ...          ...       ...       ...
#  251264 -0.015252  0.004531  1.015057
#  251267 -0.014853  0.002549  1.402989
#  251274 -0.013210  0.003912  1.717587
#  251275 -0.014575  0.004747  1.514363
#  251278 -0.013851  0.003913  1.175919
#
#  [256 rows x 12 columns],
#          clusterId                                       obsId     r  drdt  \
#  251607     251607  [56197, 60272, 62260, 68977, 70387, 76345]  3.40  0.04
#  251608     251608                [56974, 60432, 62558, 76644]  3.40  0.04
#  251609     251609                [56986, 62567, 71154, 76654]  3.40  0.04
#  251615     251615                       [56554, 70735, 76477]  3.40  0.04
#  251621     251621                [56569, 60149, 68849, 70750]  3.40  0.04
#  ...           ...                                         ...   ...   ...
#  262144     262144                [56290, 63848, 70476, 74337]  3.55 -0.04
#  262146     262146         [53818, 56290, 63848, 66067, 70476]  3.55 -0.04
#  262147     262147                       [54020, 66260, 74530]  3.55 -0.04
#  262155     262155         [53684, 65855, 65943, 74120, 74209]  3.55 -0.04
#  262157     262157                       [53697, 63727, 74222]  3.55 -0.04
#
#          cluster_epoch       x_a       y_a       z_a      vx_a      vy_a  \
#
# %%
# drop_idx2[:,3]

# %%
# drop_idx2

# %%
# drop_idx3

# %%
cof3=pd.concat(drop_idx).reset_index(drop=True)

# %%
cof3
# Out:
#        clusterId                                obsId     r  drdt  \
# 0            101                      [4, 2521, 5878]  2.00 -0.05
# 1            133               [77, 2531, 3390, 5888]  2.00 -0.05
# 2            143               [87, 2532, 3398, 5890]  2.00 -0.05
# 3            290               [53, 2529, 3372, 5885]  2.00 -0.05
# 4            291              [171, 2560, 3480, 5916]  2.00 -0.05
# ...          ...                                  ...   ...   ...
# 25671     273197         [54020, 64049, 66260, 74530]  3.65  0.05
# 25672     273206                [54126, 66359, 74628]  3.65  0.05
# 25673     273207         [53645, 63674, 65901, 74167]  3.65  0.05
# 25674     273208  [53684, 65855, 65943, 74120, 74209]  3.65  0.05
# 25675     273212                [53697, 63727, 74222]  3.65  0.05
#
#        cluster_epoch       x_a       y_a       z_a      vx_a      vy_a  \
# 0       52397.573056 -1.913481 -0.502019 -0.294626 -0.049196 -0.003277
# 1       52397.573056 -1.916374 -0.483641 -0.308446 -0.049272 -0.002180
# 2       52397.573056 -1.914580 -0.488465 -0.312780 -0.049052 -0.002575
# 3       52397.573056 -1.911367 -0.514709 -0.283764 -0.049099 -0.004260
# 4       52397.573056 -1.914981 -0.501899 -0.283670 -0.049269 -0.003443
# ...              ...       ...       ...       ...       ...       ...
# 25671   52397.573056 -3.603778 -0.206730 -0.558462  0.051504 -0.018206
# 25672   52397.573056 -3.606537 -0.197049 -0.544315  0.051104 -0.018537
# 25673   52397.573056 -3.607020 -0.213846 -0.531042  0.051122 -0.016517
# 25674   52397.573056 -3.608651 -0.208686 -0.524657  0.051176 -0.017917
# 25675   52397.573056 -3.608794 -0.190585 -0.528758  0.051082 -0.017316
#
#            vz_a       rms
# 0     -0.014363  1.676941
# 1     -0.015350  1.831745
# 2     -0.016372  1.783608
# 3     -0.013220  1.927388
# 4     -0.013497  1.769093
# ...         ...       ...
# 25671  0.006435  1.464825
# 25672  0.008896  1.935169
# 25673  0.007605  1.803797
# 25674  0.008395  1.590681
# 25675  0.007586  1.234983
#
# [25676 rows x 12 columns]

# %%
# cof2=clustered_observations.drop(index=drop_idx3).reset_index(drop=True)

# %%
# cof2

# %%
cof=ls.deduplicateClusters(cof3)

# %%
cof
# Out:
#      clusterId                                obsId     r  drdt  \
# 0          101                      [4, 2521, 5878]  2.00 -0.05
# 1          133               [77, 2531, 3390, 5888]  2.00 -0.05
# 2          143               [87, 2532, 3398, 5890]  2.00 -0.05
# 3          290               [53, 2529, 3372, 5885]  2.00 -0.05
# 4          291              [171, 2560, 3480, 5916]  2.00 -0.05
# ..         ...                                  ...   ...   ...
# 927     207382         [24183, 25184, 31297, 36819]  3.00 -0.01
# 928     213548                [53684, 65943, 74209]  3.05 -0.01
# 929     241362  [53818, 56290, 63848, 70476, 74337]  3.30  0.02
# 930     258542         [53684, 65855, 65943, 74209]  3.50 -0.02
# 931     259244                [53684, 65943, 74120]  3.50  0.01
#
#      cluster_epoch       x_a       y_a       z_a      vx_a      vy_a  \
# 0     52397.573056 -1.913481 -0.502019 -0.294626 -0.049196 -0.003277
# 1     52397.573056 -1.916374 -0.483641 -0.308446 -0.049272 -0.002180
# 2     52397.573056 -1.914580 -0.488465 -0.312780 -0.049052 -0.002575
# 3     52397.573056 -1.911367 -0.514709 -0.283764 -0.049099 -0.004260
# 4     52397.573056 -1.914981 -0.501899 -0.283670 -0.049269 -0.003443
# ..             ...       ...       ...       ...       ...       ...
# 927   52397.573056 -2.932417 -0.366458 -0.516031 -0.008318 -0.009024
# 928   52397.573056 -3.005270 -0.309991 -0.415570 -0.009097 -0.007810
# 929   52397.573056 -3.251070 -0.258395 -0.510386  0.021296 -0.013556
# 930   52397.573056 -3.456029 -0.234394 -0.498423 -0.019362 -0.006057
# 931   52397.573056 -3.456871 -0.234176 -0.497750  0.010818 -0.011140
#
#          vz_a       rms
# 0   -0.014363  1.676941
# 1   -0.015350  1.831745
# 2   -0.016372  1.783608
# 3   -0.013220  1.927388
# 4   -0.013497  1.769093
# ..        ...       ...
# 927 -0.004261  1.948268
# 928 -0.002537  1.465822
# 929  0.002524  1.034106
# 930 -0.004096  1.798889
# 931  0.001200  1.652172
#
# [932 rows x 12 columns]

# %%
len(cof['clusterId'].values)
# Out:
# 932

# %%
#cof.to_csv('heliolinc2_clusters_14nights_5x5_mean_state_filter_rms_3arcsec_1p2-3p7au.csv', index=False)

# %% [markdown]
# Drop duplicate Clusters

# %%
#clustered_observations_final=ls.deduplicateClusters(clustered_observations)

# %%
#cof=clustered_observations_final

# %%
#cof=pd.read_csv('/astro/users/eggl/epyc/projects/lsst_ssp/difi/test_data/heliolinc2_clusters_14nights_5x5_mean_state_filter_rms_3arcsec.csv')

# %%
#cof

# %%
dfobs
# Out:
#              obj          time          RA        DEC     x_obs     y_obs  \
# 0      S1009GjOa  52391.002282  171.368899 -12.504937 -0.808597 -0.599239
# 1      S1001QUsa  52391.002282  169.318742 -13.021633 -0.808597 -0.599239
# 2      S10036B8a  52391.002282  170.375067 -12.218251 -0.808597 -0.599239
# 3      S100aAWQa  52391.002282  171.392970 -14.233830 -0.808597 -0.599239
# 4      S1001DTsa  52391.002282  171.308411 -14.222651 -0.808597 -0.599239
# ...          ...           ...         ...        ...       ...       ...
# 77690         FD  52404.143830  168.246340 -10.054649 -0.658676 -0.765370
# 77691         FD  52404.143830  168.169379 -10.115589 -0.658676 -0.765370
# 77692         FD  52404.143830  168.197432 -10.128132 -0.658676 -0.765370
# 77693         FD  52404.143830  168.273093 -10.004619 -0.658676 -0.765370
# 77694         FD  52404.143830  168.127077 -10.111775 -0.658676 -0.765370
#
#           z_obs    vx_obs    vy_obs    vz_obs  night  obsId  objId
# 0     -0.000026  0.009826 -0.014054  0.000076      0      0    839
# 1     -0.000026  0.009826 -0.014054  0.000076      0      1    164
# 2     -0.000026  0.009826 -0.014054  0.000076      0      2    319
# 3     -0.000026  0.009826 -0.014054  0.000076      0      3   1580
# 4     -0.000026  0.009826 -0.014054  0.000076      0      4    144
# ...         ...       ...       ...       ...    ...    ...    ...
# 77690 -0.000006  0.012875 -0.011480  0.000081     13  77690      0
# 77691 -0.000006  0.012875 -0.011480  0.000081     13  77691      0
# 77692 -0.000006  0.012875 -0.011480  0.000081     13  77692      0
# 77693 -0.000006  0.012875 -0.011480  0.000081     13  77693      0
# 77694 -0.000006  0.012875 -0.011480  0.000081     13  77694      0
#
# [77695 rows x 13 columns]

# %%
# Save dataframe to csv file for DIFI
cof.to_csv('HelioLinC2_clusters_Veres_5x5deb_14nights.csv', index=False)

# %% [markdown]
# ## Performance Analysis

# %%
import difi_analysis as da
import os

# %%
DATA_DIR = "/epyc/projects/lsst_ssp/difi/test_data"
# Read observations into a dataframe
observations = pd.read_csv(
    os.path.join(DATA_DIR, "Veres_5x5deb_14nights.csv"), 
    sep=",", 
    dtype={
        "obsId" : str,
        "obj" : str,
        "objId" : str,
    },
    index_col=False
)
# Read SSP linkages
linkages = pd.read_csv(
    #os.path.join(DATA_DIR, "heliolinc2_clusters_14nights_5x5_mean_state_filter_rms_3arcsec.csv"), 
    os.path.join(DATA_DIR, "HelioLinC2_clusters_Veres_5x5deb_14nights.csv"),
    sep=",", 
    index_col=False
)

# %%
# Run analysis
observations, linkageMembers, allLinkages, allTruths, summary = da.analyzePerformance(observations, linkages)
# Out:
# Analyzing observations...
# All
# ----------------------------------------------------------------
#                                    Number  (% class)  (% total)
# All linkages:                         932  (100.00%)  (100.00%)
# Pure linkages:                        932  (100.00%)  (100.00%)
# Complete pure linkages:               105  ( 11.27%)  ( 11.27%)
# Partial linkages:                       0  (  0.00%)  (  0.00%)
# Pure and partial linkages:            932  (100.00%)  (100.00%)
# Mixed linkages:                         0  (  0.00%)  (  0.00%)
#
#                                    Number  (% class) (% findable)
# Unique All:
#  ..in pure linkages:                  714  (  1.10%)  ( 31.72%)
#  ..in complete pure linkages:         105  (  0.16%)  (  4.66%)
#  ..in partial linkages:                 0  (  0.00%)  (  0.00%)
#  ..in pure and partial linkages:      714  (  1.10%)  ( 31.72%)
#  ..in mixed linkages:                   0  (  0.00%)  (  0.00%)
#  ..only in pure linkages:             714  (  1.10%)  ( 31.72%)
#  ..only in partial linkages:            0  (  0.00%)  (  0.00%)
#
# Findable:                        2251
# Found:                           714
# Findable found:                  714
# Findable missed:                 1537
# Not findable found:              0
# Not findable missed:             62537
#
# Completeness (findable found / findable):             31.72%
#
# MBA
# ----------------------------------------------------------------
#                                    Number  (% class)  (% total)
# All linkages:                         932  (100.00%)  (100.00%)
# Pure linkages:                        932  (100.00%)  (100.00%)
# Complete pure linkages:               105  ( 11.27%)  ( 11.27%)
# Partial linkages:                       0  (  0.00%)  (  0.00%)
# Pure and partial linkages:            932  (100.00%)  (100.00%)
# Mixed linkages:                         0  (  0.00%)  (  0.00%)
#
#                                    Number  (% class) (% findable)
# Unique MBA:
#  ..in pure linkages:                  714  ( 20.65%)  ( 31.85%)
#  ..in complete pure linkages:         105  (  3.04%)  (  4.68%)
#  ..in partial linkages:                 0  (  0.00%)  (  0.00%)
#  ..in pure and partial linkages:      714  ( 20.65%)  ( 31.85%)
#  ..in mixed linkages:                   0  (  0.00%)  (  0.00%)
#  ..only in pure linkages:             714  ( 20.65%)  ( 31.85%)
#  ..only in partial linkages:            0  (  0.00%)  (  0.00%)
#
# Findable:                        2242
# Found:                           714
# Findable found:                  714
# Findable missed:                 1528
# Not findable found:              0
# Not findable missed:             1216
#
# Completeness (findable found / findable):             31.85%
#
# NOISE 2
# ----------------------------------------------------------------
#                                    Number  (% class)  (% total)
# All linkages:                           0  (   nan%)  (  0.00%)
# Pure linkages:                          0  (   nan%)  (  0.00%)
# Complete pure linkages:                 0  (   nan%)  (  0.00%)
# Partial linkages:                       0  (   nan%)  (  0.00%)
# Pure and partial linkages:              0  (   nan%)  (  0.00%)
# Mixed linkages:                         0  (   nan%)  (  0.00%)
#
#                                    Number  (% class) (% findable)
# Unique NOISE 2:
#  ..in pure linkages:                    0  (  0.00%)  (   nan%)
#  ..in complete pure linkages:           0  (  0.00%)  (   nan%)
#  ..in partial linkages:                 0  (  0.00%)  (   nan%)
#  ..in pure and partial linkages:        0  (  0.00%)  (   nan%)
#  ..in mixed linkages:                   0  (  0.00%)  (   nan%)
#  ..only in pure linkages:               0  (  0.00%)  (   nan%)
#  ..only in partial linkages:            0  (  0.00%)  (   nan%)
#
# Findable:                        0
# Found:                           0
# Findable found:                  0
# Findable missed:                 0
# Not findable found:              0
# Not findable missed:             16363
#
# Completeness (findable found / findable):              0.00%
#
# NOISE 1
# ----------------------------------------------------------------
#                                    Number  (% class)  (% total)
# All linkages:                           0  (   nan%)  (  0.00%)
# Pure linkages:                          0  (   nan%)  (  0.00%)
# Complete pure linkages:                 0  (   nan%)  (  0.00%)
# Partial linkages:                       0  (   nan%)  (  0.00%)
# Pure and partial linkages:              0  (   nan%)  (  0.00%)
# Mixed linkages:                         0  (   nan%)  (  0.00%)
#
#                                    Number  (% class) (% findable)
# Unique NOISE 1:
#  ..in pure linkages:                    0  (  0.00%)  (   nan%)
#  ..in complete pure linkages:           0  (  0.00%)  (   nan%)
#  ..in partial linkages:                 0  (  0.00%)  (   nan%)
#  ..in pure and partial linkages:        0  (  0.00%)  (   nan%)
#  ..in mixed linkages:                   0  (  0.00%)  (   nan%)
#  ..only in pure linkages:               0  (  0.00%)  (   nan%)
#  ..only in partial linkages:            0  (  0.00%)  (   nan%)
#
# Findable:                        0
# Found:                           0
# Findable found:                  0
# Findable missed:                 0
# Not findable found:              0
# Not findable missed:             44948
#
# Completeness (findable found / findable):              0.00%
#
# NEO
# ----------------------------------------------------------------
#                                    Number  (% class)  (% total)
# All linkages:                           0  (   nan%)  (  0.00%)
# Pure linkages:                          0  (   nan%)  (  0.00%)
# Complete pure linkages:                 0  (   nan%)  (  0.00%)
# Partial linkages:                       0  (   nan%)  (  0.00%)
# Pure and partial linkages:              0  (   nan%)  (  0.00%)
# Mixed linkages:                         0  (   nan%)  (  0.00%)
#
#                                    Number  (% class) (% findable)
# Unique NEO:
#  ..in pure linkages:                    0  (  0.00%)  (  0.00%)
#  ..in complete pure linkages:           0  (  0.00%)  (  0.00%)
#  ..in partial linkages:                 0  (  0.00%)  (  0.00%)
#  ..in pure and partial linkages:        0  (  0.00%)  (  0.00%)
#  ..in mixed linkages:                   0  (  0.00%)  (  0.00%)
#  ..only in pure linkages:               0  (  0.00%)  (  0.00%)
#  ..only in partial linkages:            0  (  0.00%)  (  0.00%)
#
# Findable:                        9
# Found:                           0
# Findable found:                  0
# Findable missed:                 9
# Not findable found:              0
# Not findable missed:             10
#
# Completeness (findable found / findable):              0.00%
#
# All
# ----------------------------------------------------------------
#                                    Number  (% class)  (% total)
# All linkages:                         932  (100.00%)  (100.00%)
# Pure linkages:                        932  (100.00%)  (100.00%)
# Complete pure linkages:               105  ( 11.27%)  ( 11.27%)
# Partial linkages:                       0  (  0.00%)  (  0.00%)
# Pure and partial linkages:            932  (100.00%)  (100.00%)
# Mixed linkages:                         0  (  0.00%)  (  0.00%)
#
#                                    Number  (% class) (% findable)
# Unique All:
#  ..in pure linkages:                  714  (  1.10%)  ( 93.70%)
#  ..in complete pure linkages:         105  (  0.16%)  ( 13.78%)
#  ..in partial linkages:                 0  (  0.00%)  (  0.00%)
#  ..in pure and partial linkages:      714  (  1.10%)  ( 93.70%)
#  ..in mixed linkages:                   0  (  0.00%)  (  0.00%)
#  ..only in pure linkages:             714  (  1.10%)  ( 93.70%)
#  ..only in partial linkages:            0  (  0.00%)  (  0.00%)
#
# Findable:                        762
# Found:                           714
# Findable found:                  301
# Findable missed:                 461
# Not findable found:              413
# Not findable missed:             63613
#
# Completeness (findable found / findable):             39.50%
#
# MBA
# ----------------------------------------------------------------
#                                    Number  (% class)  (% total)
# All linkages:                         932  (100.00%)  (100.00%)
# Pure linkages:                        932  (100.00%)  (100.00%)
# Complete pure linkages:               105  ( 11.27%)  ( 11.27%)
# Partial linkages:                       0  (  0.00%)  (  0.00%)
# Pure and partial linkages:            932  (100.00%)  (100.00%)
# Mixed linkages:                         0  (  0.00%)  (  0.00%)
#
#                                    Number  (% class) (% findable)
# Unique MBA:
#  ..in pure linkages:                  714  ( 20.65%)  ( 93.70%)
#  ..in complete pure linkages:         105  (  3.04%)  ( 13.78%)
#  ..in partial linkages:                 0  (  0.00%)  (  0.00%)
#  ..in pure and partial linkages:      714  ( 20.65%)  ( 93.70%)
#  ..in mixed linkages:                   0  (  0.00%)  (  0.00%)
#  ..only in pure linkages:             714  ( 20.65%)  ( 93.70%)
#  ..only in partial linkages:            0  (  0.00%)  (  0.00%)
#
# Findable:                        762
# Found:                           714
# Findable found:                  301
# Findable missed:                 461
# Not findable found:              413
# Not findable missed:             2283
#
# Completeness (findable found / findable):             39.50%
#
# NOISE 2
# ----------------------------------------------------------------
#                                    Number  (% class)  (% total)
# All linkages:                           0  (   nan%)  (  0.00%)
# Pure linkages:                          0  (   nan%)  (  0.00%)
# Complete pure linkages:                 0  (   nan%)  (  0.00%)
# Partial linkages:                       0  (   nan%)  (  0.00%)
# Pure and partial linkages:              0  (   nan%)  (  0.00%)
# Mixed linkages:                         0  (   nan%)  (  0.00%)
#
#                                    Number  (% class) (% findable)
# Unique NOISE 2:
#  ..in pure linkages:                    0  (  0.00%)  (   nan%)
#  ..in complete pure linkages:           0  (  0.00%)  (   nan%)
#  ..in partial linkages:                 0  (  0.00%)  (   nan%)
#  ..in pure and partial linkages:        0  (  0.00%)  (   nan%)
#  ..in mixed linkages:                   0  (  0.00%)  (   nan%)
#  ..only in pure linkages:               0  (  0.00%)  (   nan%)
#  ..only in partial linkages:            0  (  0.00%)  (   nan%)
#
# Findable:                        0
# Found:                           0
# Findable found:                  0
# Findable missed:                 0
# Not findable found:              0
# Not findable missed:             16363
#
# Completeness (findable found / findable):              0.00%
#
# NOISE 1
# ----------------------------------------------------------------
#                                    Number  (% class)  (% total)
# All linkages:                           0  (   nan%)  (  0.00%)
# Pure linkages:                          0  (   nan%)  (  0.00%)
# Complete pure linkages:                 0  (   nan%)  (  0.00%)
# Partial linkages:                       0  (   nan%)  (  0.00%)
# Pure and partial linkages:              0  (   nan%)  (  0.00%)
# Mixed linkages:                         0  (   nan%)  (  0.00%)
#
#                                    Number  (% class) (% findable)
# Unique NOISE 1:
#  ..in pure linkages:                    0  (  0.00%)  (   nan%)
#  ..in complete pure linkages:           0  (  0.00%)  (   nan%)
#  ..in partial linkages:                 0  (  0.00%)  (   nan%)
#  ..in pure and partial linkages:        0  (  0.00%)  (   nan%)
#  ..in mixed linkages:                   0  (  0.00%)  (   nan%)
#  ..only in pure linkages:               0  (  0.00%)  (   nan%)
#  ..only in partial linkages:            0  (  0.00%)  (   nan%)
#
# Findable:                        0
# Found:                           0
# Findable found:                  0
# Findable missed:                 0
# Not findable found:              0
# Not findable missed:             44948
#
# Completeness (findable found / findable):              0.00%
#
# NEO
# ----------------------------------------------------------------
#                                    Number  (% class)  (% total)
# All linkages:                           0  (   nan%)  (  0.00%)
# Pure linkages:                          0  (   nan%)  (  0.00%)
# Complete pure linkages:                 0  (   nan%)  (  0.00%)
# Partial linkages:                       0  (   nan%)  (  0.00%)
# Pure and partial linkages:              0  (   nan%)  (  0.00%)
# Mixed linkages:                         0  (   nan%)  (  0.00%)
#
#                                    Number  (% class) (% findable)
# Unique NEO:
#  ..in pure linkages:                    0  (  0.00%)  (   nan%)
#  ..in complete pure linkages:           0  (  0.00%)  (   nan%)
#  ..in partial linkages:                 0  (  0.00%)  (   nan%)
#  ..in pure and partial linkages:        0  (  0.00%)  (   nan%)
#  ..in mixed linkages:                   0  (  0.00%)  (   nan%)
#  ..only in pure linkages:               0  (  0.00%)  (   nan%)
#  ..only in partial linkages:            0  (  0.00%)  (   nan%)
#
# Findable:                        0
# Found:                           0
# Findable found:                  0
# Findable missed:                 0
# Not findable found:              0
# Not findable missed:             19
#
# Completeness (findable found / findable):              0.00%
